# %% [markdown]
# Install geohash package

# %%
pip install python-geohash
# Out:
# Requirement already satisfied: python-geohash in /opt/conda/lib/python3.8/site-packages (0.8.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0 pyspark-shell'
from datetime import datetime, timedelta
import random
import re
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql import types as T
# import statements
import json 
import geohash 

topic_name = 'Assignment3'
hostip = "192.168.0.108" # change it to your IP

#instantiate Spark 
spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('[Demo] Spark Streaming from Kafka into MongoDB')
        .getOrCreate()
)

#configure reading from kafka streams
# converts stream into a dataframe
producer_df = (
    spark.readStream.format('kafka')
    .option('kafka.bootstrap.servers', f'{hostip}:9092')
    .option('subscribe', "Producer1, Producer2, Producer3") #set spark to listen to 3 streams
    .load()
)

# %%
producer_df.select('value')
# Out:
# DataFrame[value: binary]

# %%
import copy

"""
Input
batch: a list of json records
collection: string representation of database's collection name to append add to

Explanation
This pushes records to mongodb databaase
"""
def push_batch_tomongodb(batch, collection):    
    mongo_client = MongoClient(host=f'{hostip}', port=27017)
    db = mongo_client['fit3182_db']
    collection_db = db[collection]
    for record in batch:
        collection_db.insert_one(record)
    
    mongo_client.close()
    
    
"""
Input
df: dataframe

Explanation
This is called for a batch of new records received every 10 seconds (1 day)
"""
def foreach_batch_function(df, epoch_id):   
    #map dataframe to a list 
    data = df.collect()
    temp_aqua = []
    temp_terra = []
    climate = None
    climate_lat = None
    climate_long = None
    #seperate data based on stream producer
    for row in data:
        decoded_data = row.value.decode('utf-8')
        json_value = json.loads(decoded_data)
        producer = json_value["producer"]
        
        if producer== "Producer1":
            result = re.match(r"(\d+\.\d+)([A-Za-z]+)", json_value['precipitation '].strip()) #seperate precipitation data into seperate numeric and aphabert part
            numeric_part_precipitation = float(result.group(1)) #measurement of precipitation
            alphabetic_part_precipitation = result.group(2) #flag representation info
            datetime_obj = datetime.fromisoformat(json_value['created_on']) 

            #map climate schema
            climateSchema = {}
            climateSchema["date"] = datetime_obj
            climateSchema["station"] = random.randint(1, 10000) #randomly created station number
            climateSchema["relative_humidity"] = json_value["relative_humidity"]
            climateSchema["air_temperature_celsius"] = json_value["air_temperature_celcius"]
            climateSchema["windspeed_knots"] = json_value["windspeed_knots"]
            climateSchema["max_wind_speed"] = json_value["max_wind_speed"]
            climateSchema["measure"] = numeric_part_precipitation
            climateSchema["flag"] = alphabetic_part_precipitation
            climateSchema["GHI_w/m2"] = json_value["GHI_w/m2"]
            climate_lat = json_value["latitude"]
            climate_long = json_value["longitude"]
            climate = climateSchema
            
        else:
            datetime_obj = datetime.fromisoformat(json_value['created_on'])
            date_obj = datetime_obj.date()  # Extract the date part
            date_part = datetime(date_obj.year, date_obj.month, date_obj.day)  # Create new datetime object using the extracted date
            
            #map hotspot schema
            hotspotSchema = {}
            hotspotSchema["date"] = date_part
            hotspotSchema["datetime"] = datetime_obj
            hotspotSchema["latitude"] = json_value["latitude"]
            hotspotSchema["longitude"] = json_value["longitude"]
            hotspotSchema["confidence"] = json_value["confidence"]
            hotspotSchema["surface_temperature_celsius"] = json_value["surface_temperature_celcius"]
            
            if producer == "Producer2":
                temp_aqua.append(hotspotSchema)
            elif producer == "Producer3":
                temp_terra.append(hotspotSchema)
            
    #handle when there was no climate data is found
    if climate == None:
        print("-----------NO CLIMATE DATA FOUND-----------")
        return
    
    #encode3 for climate loc
    geohash3Climate = geohash.encode(climate_lat, climate_long, 3)
    
    fire_aqua = []
    temp_fires = []
    
    #find all nearby (geohash precision 3) fires to the station
    for aqua in temp_aqua:
        geohash3 = geohash.encode(aqua['latitude'], aqua['longitude'], 3)
        if geohash3 == geohash3Climate:
            temp_fires.append(aqua)
    
    for terra in temp_terra:
        geohash3 = geohash.encode(terra['latitude'], terra['longitude'], 3)
        if geohash3 == geohash3Climate:
            temp_fires.append(terra)
    
    
    if len(temp_fires) < 1: #if there are no fires nearby found
        #insert climate data   
        print("---------------NO FIRES NEARBY------------")
        print(climate)
        push_batch_tomongodb([climate], "climate")
        return
    
    hashMap = {}
    fires = []
    
    #create hashmap of fires hashed by geohash 5
    #this essentially groups fires with the same geohash 5
    for fire in temp_fires: 
        geohash5 = geohash.encode(float(fire['latitude']), float(fire['longitude']), 5)
        if geohash5 in hashMap.keys():
            hashMap[geohash5].append(fire)
        else:
            hashMap[geohash5] = [fire]
    
    for key in hashMap.keys():
        record = {}
        match_hotspots = hashMap[key]
        avg_surface_temp = 0
        avg_confidence = 0
        earlier_date = None
        earlier_datetime = None
        centre_lat = 0
        centre_long = 0
        isFirstItr = True
        #this iterates through every fire in each hash partition 
        #and combines the records if they are the same fire
        for fire in match_hotspots:   
            
            #check if this is the first fire
            if isFirstItr == True:
                avg_surface_temp = fire['surface_temperature_celsius']
                avg_confidence = fire['confidence']
                centre_lat = fire['latitude']
                centre_long = fire['longitude']
                isFirstItr = False
            else:
                avg_surface_temp = float(fire['surface_temperature_celsius'] + avg_surface_temp) / 2 
                avg_confidence = float(fire['confidence'] + avg_confidence) / 2               
                #find centre point of location
                centre_lat = float((centre_lat + fire['latitude']) /2)
                centre_long = float((centre_long + fire['longitude']) /2)
            
            #this takes the earliest date 
            if earlier_date == None or earlier_date > fire['datetime']:
                #use earlier date to signify the earliest recorded date and time of fire
                earlier_date = fire['date']
                earlier_datetime = fire['datetime']

        
        #determine the type of fire
        if climate['air_temperature_celsius'] > 20 and climate['GHI_w/m2'] > 180:
            record['type'] = "natural"
        else:
            record['type'] = "other"
        
        record['date'] = earlier_date
        record["datetime"] = earlier_datetime
        record['surface_temperature_celsius'] = avg_surface_temp
        record['confidence'] = avg_confidence
        record['latitude'] = centre_lat
        record['longitude'] = centre_long
        fires.append(record)
    
    #once fire records have been processed, the records are added to mongodb
    print("--------------CLIMATE-------------")
    print(climate)
    push_batch_tomongodb([climate], "climate")
    print("--------------FIRES-------------")
    print(fires)
    push_batch_tomongodb(fires, "hotspots")

# %%
writer = (
    producer_df.writeStream \
    .outputMode('append') \
    .foreachBatch(foreach_batch_function) \
    .trigger(processingTime="10 seconds")
)

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopping query.')
finally:
    query.stop()
# Out:
# -----------NO CLIMATE DATA FOUND-----------
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 14, 0, 0), 'station': 7570, 'relative_humidity': 48.1, 'air_temperature_celsius': 14, 'windspeed_knots': 13.7, 'max_wind_speed': 19.0, 'measure': 0.35, 'flag': 'G', 'GHI_w/m2': 122}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 12, 0, 0), 'datetime': datetime.datetime(2025, 3, 12, 9, 36), 'surface_temperature_celsius': 56.0, 'confidence': 83.0, 'latitude': -36.7217, 'longitude': 141.6378}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 15, 0, 0), 'station': 7941, 'relative_humidity': 43.6, 'air_temperature_celsius': 10, 'windspeed_knots': 9.7, 'max_wind_speed': 14.0, 'measure': 0.2, 'flag': 'G', 'GHI_w/m2': 90}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 13, 0, 0), 'datetime': datetime.datetime(2025, 3, 13, 19, 12), 'surface_temperature_celsius': 42.0, 'confidence': 64.0, 'latitude': -36.309, 'longitude': 145.6878}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 16, 0, 0), 'station': 6956, 'relative_humidity': 45.7, 'air_temperature_celsius': 14, 'windspeed_knots': 9.2, 'max_wind_speed': 15.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 124}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 17, 0, 0), 'station': 4132, 'relative_humidity': 47.1, 'air_temperature_celsius': 10, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 88}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 18, 0, 0), 'station': 856, 'relative_humidity': 58.8, 'air_temperature_celsius': 23, 'windspeed_knots': 8.8, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 183}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 3, 17, 0, 0), 'datetime': datetime.datetime(2025, 3, 17, 0, 0), 'surface_temperature_celsius': 40.0, 'confidence': 58.0, 'latitude': -36.4944, 'longitude': 141.8992}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 19, 0, 0), 'station': 8918, 'relative_humidity': 42.2, 'air_temperature_celsius': 9, 'windspeed_knots': 6.4, 'max_wind_speed': 9.9, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 82}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 17, 0, 0), 'datetime': datetime.datetime(2025, 3, 17, 14, 24), 'surface_temperature_celsius': 55.0, 'confidence': 81.0, 'latitude': -36.9912, 'longitude': 142.0122}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 20, 0, 0), 'station': 4344, 'relative_humidity': 44.8, 'air_temperature_celsius': 10, 'windspeed_knots': 8.8, 'max_wind_speed': 14.0, 'measure': 0.39, 'flag': 'G', 'GHI_w/m2': 89}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 21, 0, 0), 'station': 3370, 'relative_humidity': 64.5, 'air_temperature_celsius': 21, 'windspeed_knots': 10.6, 'max_wind_speed': 15.9, 'measure': 1.26, 'flag': 'G', 'GHI_w/m2': 158}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 22, 0, 0), 'station': 5308, 'relative_humidity': 53.0, 'air_temperature_celsius': 17, 'windspeed_knots': 14.6, 'max_wind_speed': 22.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 142}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 21, 0, 0), 'datetime': datetime.datetime(2025, 3, 21, 0, 0), 'surface_temperature_celsius': 62.0, 'confidence': 87.0, 'latitude': -37.2793, 'longitude': 143.8934}, {'type': 'other', 'date': datetime.datetime(2025, 3, 21, 0, 0), 'datetime': datetime.datetime(2025, 3, 21, 0, 0), 'surface_temperature_celsius': 79.0, 'confidence': 96.0, 'latitude': -36.5987, 'longitude': 144.4995}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 23, 0, 0), 'station': 2794, 'relative_humidity': 44.5, 'air_temperature_celsius': 12, 'windspeed_knots': 11.1, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 108}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 24, 0, 0), 'station': 8368, 'relative_humidity': 44.0, 'air_temperature_celsius': 14, 'windspeed_knots': 14.4, 'max_wind_speed': 23.9, 'measure': 0.16, 'flag': 'G', 'GHI_w/m2': 126}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 22, 0, 0), 'datetime': datetime.datetime(2025, 3, 22, 19, 12), 'surface_temperature_celsius': 70.0, 'confidence': 92.0, 'latitude': -36.5828, 'longitude': 144.5775}, {'type': 'other', 'date': datetime.datetime(2025, 3, 23, 0, 0), 'datetime': datetime.datetime(2025, 3, 23, 0, 0), 'surface_temperature_celsius': 88.0, 'confidence': 100.0, 'latitude': -37.9071, 'longitude': 143.538}, {'type': 'other', 'date': datetime.datetime(2025, 3, 23, 0, 0), 'datetime': datetime.datetime(2025, 3, 23, 4, 48), 'surface_temperature_celsius': 85.0, 'confidence': 99.0, 'latitude': -37.8885, 'longitude': 143.9157}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 25, 0, 0), 'station': 9025, 'relative_humidity': 58.1, 'air_temperature_celsius': 17, 'windspeed_knots': 11.7, 'max_wind_speed': 19.0, 'measure': 0.04, 'flag': 'G', 'GHI_w/m2': 136}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 3, 26, 0, 0), 'station': 4776, 'relative_humidity': 61.6, 'air_temperature_celsius': 24, 'windspeed_knots': 7.7, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 186}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 27, 0, 0), 'station': 2439, 'relative_humidity': 51.0, 'air_temperature_celsius': 15, 'windspeed_knots': 9.6, 'max_wind_speed': 15.9, 'measure': 0.16, 'flag': 'G', 'GHI_w/m2': 128}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 25, 0, 0), 'datetime': datetime.datetime(2025, 3, 25, 19, 12), 'surface_temperature_celsius': 64.0, 'confidence': 89.0, 'latitude': -37.4169, 'longitude': 145.5926}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 28, 0, 0), 'station': 7889, 'relative_humidity': 50.8, 'air_temperature_celsius': 16, 'windspeed_knots': 5.8, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 136}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 27, 0, 0), 'datetime': datetime.datetime(2025, 3, 27, 0, 0), 'surface_temperature_celsius': 58.0, 'confidence': 80.0, 'latitude': -36.4023, 'longitude': 145.7705}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 29, 0, 0), 'station': 2058, 'relative_humidity': 57.0, 'air_temperature_celsius': 22, 'windspeed_knots': 8.5, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 178}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 27, 0, 0), 'datetime': datetime.datetime(2025, 3, 27, 9, 36), 'surface_temperature_celsius': 87.0, 'confidence': 100.0, 'latitude': -36.345, 'longitude': 143.4256}, {'type': 'other', 'date': datetime.datetime(2025, 3, 27, 0, 0), 'datetime': datetime.datetime(2025, 3, 27, 19, 12), 'surface_temperature_celsius': 78.0, 'confidence': 96.0, 'latitude': -36.1002, 'longitude': 142.3405}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 30, 0, 0), 'station': 9358, 'relative_humidity': 38.4, 'air_temperature_celsius': 13, 'windspeed_knots': 11.5, 'max_wind_speed': 16.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 122}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 28, 0, 0), 'datetime': datetime.datetime(2025, 3, 28, 19, 12), 'surface_temperature_celsius': 43.0, 'confidence': 64.0, 'latitude': -37.6606, 'longitude': 142.9932}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 3, 31, 0, 0), 'station': 3638, 'relative_humidity': 41.6, 'air_temperature_celsius': 14, 'windspeed_knots': 13.1, 'max_wind_speed': 18.1, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 128}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 30, 0, 0), 'datetime': datetime.datetime(2025, 3, 30, 4, 48), 'surface_temperature_celsius': 109.0, 'confidence': 75.0, 'latitude': -35.8125, 'longitude': 142.1286}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 1, 0, 0), 'station': 1207, 'relative_humidity': 50.4, 'air_temperature_celsius': 13, 'windspeed_knots': 7.9, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 111}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 31, 0, 0), 'datetime': datetime.datetime(2025, 3, 31, 4, 48), 'surface_temperature_celsius': 48.0, 'confidence': 52.0, 'latitude': -36.5646, 'longitude': 142.3068}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 2, 0, 0), 'station': 1173, 'relative_humidity': 41.5, 'air_temperature_celsius': 15, 'windspeed_knots': 17.0, 'max_wind_speed': 28.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 138}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 3, 31, 0, 0), 'datetime': datetime.datetime(2025, 3, 31, 19, 12), 'surface_temperature_celsius': 47.0, 'confidence': 77.0, 'latitude': -37.586, 'longitude': 148.038}, {'type': 'other', 'date': datetime.datetime(2025, 4, 1, 0, 0), 'datetime': datetime.datetime(2025, 4, 1, 0, 0), 'surface_temperature_celsius': 78.0, 'confidence': 86.0, 'latitude': -37.6775, 'longitude': 148.5131}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 3, 0, 0), 'station': 3539, 'relative_humidity': 43.1, 'air_temperature_celsius': 8, 'windspeed_knots': 3.4, 'max_wind_speed': 7.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 73}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 2, 0, 0), 'datetime': datetime.datetime(2025, 4, 2, 0, 0), 'surface_temperature_celsius': 56.0, 'confidence': 86.0, 'latitude': -37.57, 'longitude': 148.034}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 4, 0, 0), 'station': 7715, 'relative_humidity': 54.9, 'air_temperature_celsius': 16, 'windspeed_knots': 5.9, 'max_wind_speed': 9.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 132}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 3, 0, 0), 'datetime': datetime.datetime(2025, 4, 3, 9, 36), 'surface_temperature_celsius': 65.0, 'confidence': 89.0, 'latitude': -36.73, 'longitude': 143.935}, {'type': 'other', 'date': datetime.datetime(2025, 4, 2, 0, 0), 'datetime': datetime.datetime(2025, 4, 2, 4, 48), 'surface_temperature_celsius': 44.0, 'confidence': 68.0, 'latitude': -36.6599, 'longitude': 144.6129}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 5, 0, 0), 'station': 8562, 'relative_humidity': 40.8, 'air_temperature_celsius': 9, 'windspeed_knots': 6.7, 'max_wind_speed': 15.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 83}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 6, 0, 0), 'station': 1250, 'relative_humidity': 48.3, 'air_temperature_celsius': 28, 'windspeed_knots': 11.9, 'max_wind_speed': 22.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 243}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 7, 0, 0), 'station': 7843, 'relative_humidity': 53.5, 'air_temperature_celsius': 17, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 141}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 8, 0, 0), 'station': 9091, 'relative_humidity': 41.2, 'air_temperature_celsius': 9, 'windspeed_knots': 10.0, 'max_wind_speed': 13.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 83}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 6, 0, 0), 'datetime': datetime.datetime(2025, 4, 6, 9, 36), 'surface_temperature_celsius': 53.0, 'confidence': 79.0, 'latitude': -36.932, 'longitude': 141.9456}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 9, 0, 0), 'station': 6179, 'relative_humidity': 59.0, 'air_temperature_celsius': 23, 'windspeed_knots': 6.0, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 182}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 10, 0, 0), 'station': 6826, 'relative_humidity': 35.6, 'air_temperature_celsius': 10, 'windspeed_knots': 14.5, 'max_wind_speed': 20.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 96}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 8, 0, 0), 'datetime': datetime.datetime(2025, 4, 8, 19, 12), 'surface_temperature_celsius': 65.0, 'confidence': 100.0, 'latitude': -37.396, 'longitude': 148.086}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 11, 0, 0), 'station': 4435, 'relative_humidity': 52.8, 'air_temperature_celsius': 19, 'windspeed_knots': 12.5, 'max_wind_speed': 21.0, 'measure': 0.47, 'flag': 'G', 'GHI_w/m2': 159}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 10, 0, 0), 'datetime': datetime.datetime(2025, 4, 10, 4, 48), 'surface_temperature_celsius': 54.0, 'confidence': 67.0, 'latitude': -36.942, 'longitude': 143.292}, {'type': 'other', 'date': datetime.datetime(2025, 4, 9, 0, 0), 'datetime': datetime.datetime(2025, 4, 9, 4, 48), 'surface_temperature_celsius': 53.0, 'confidence': 66.0, 'latitude': -37.7069, 'longitude': 142.1573}, {'type': 'other', 'date': datetime.datetime(2025, 4, 9, 0, 0), 'datetime': datetime.datetime(2025, 4, 9, 9, 36), 'surface_temperature_celsius': 54.0, 'confidence': 81.0, 'latitude': -37.9187, 'longitude': 143.3385}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 12, 0, 0), 'station': 9717, 'relative_humidity': 60.1, 'air_temperature_celsius': 24, 'windspeed_knots': 8.0, 'max_wind_speed': 13.0, 'measure': 0.12, 'flag': 'G', 'GHI_w/m2': 188}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 13, 0, 0), 'station': 1664, 'relative_humidity': 58.4, 'air_temperature_celsius': 28, 'windspeed_knots': 11.9, 'max_wind_speed': 18.1, 'measure': 0.04, 'flag': 'G', 'GHI_w/m2': 223}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 4, 11, 0, 0), 'datetime': datetime.datetime(2025, 4, 11, 4, 48), 'surface_temperature_celsius': 115.0, 'confidence': 100.0, 'latitude': -36.6029, 'longitude': 144.6259}, {'type': 'natural', 'date': datetime.datetime(2025, 4, 11, 0, 0), 'datetime': datetime.datetime(2025, 4, 11, 9, 36), 'surface_temperature_celsius': 52.0, 'confidence': 79.0, 'latitude': -36.6672, 'longitude': 143.8631}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 14, 0, 0), 'station': 3895, 'relative_humidity': 42.1, 'air_temperature_celsius': 10, 'windspeed_knots': 9.4, 'max_wind_speed': 15.0, 'measure': 0.13, 'flag': 'B', 'GHI_w/m2': 91}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 12, 0, 0), 'datetime': datetime.datetime(2025, 4, 12, 0, 0), 'surface_temperature_celsius': 58.0, 'confidence': 84.0, 'latitude': -36.1456, 'longitude': 141.9066}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 15, 0, 0), 'station': 3907, 'relative_humidity': 44.6, 'air_temperature_celsius': 8, 'windspeed_knots': 3.9, 'max_wind_speed': 8.0, 'measure': 0.39, 'flag': 'G', 'GHI_w/m2': 72}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 16, 0, 0), 'station': 5136, 'relative_humidity': 48.2, 'air_temperature_celsius': 12, 'windspeed_knots': 7.3, 'max_wind_speed': 11.1, 'measure': 0.03, 'flag': 'G', 'GHI_w/m2': 104}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 17, 0, 0), 'station': 2350, 'relative_humidity': 48.8, 'air_temperature_celsius': 12, 'windspeed_knots': 4.2, 'max_wind_speed': 7.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 104}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 18, 0, 0), 'station': 1118, 'relative_humidity': 42.7, 'air_temperature_celsius': 12, 'windspeed_knots': 10.0, 'max_wind_speed': 15.9, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 109}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 16, 0, 0), 'datetime': datetime.datetime(2025, 4, 16, 14, 24), 'surface_temperature_celsius': 52.0, 'confidence': 79.0, 'latitude': -35.7638, 'longitude': 142.1215}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 19, 0, 0), 'station': 3523, 'relative_humidity': 49.9, 'air_temperature_celsius': 12, 'windspeed_knots': 6.1, 'max_wind_speed': 13.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 103}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 20, 0, 0), 'station': 9246, 'relative_humidity': 57.4, 'air_temperature_celsius': 21, 'windspeed_knots': 10.7, 'max_wind_speed': 22.9, 'measure': 0.67, 'flag': 'G', 'GHI_w/m2': 169}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 21, 0, 0), 'station': 8891, 'relative_humidity': 62.0, 'air_temperature_celsius': 22, 'windspeed_knots': 7.9, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 170}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 22, 0, 0), 'station': 8598, 'relative_humidity': 46.9, 'air_temperature_celsius': 22, 'windspeed_knots': 12.9, 'max_wind_speed': 19.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 193}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 23, 0, 0), 'station': 9736, 'relative_humidity': 41.0, 'air_temperature_celsius': 8, 'windspeed_knots': 11.0, 'max_wind_speed': 16.9, 'measure': 0.47, 'flag': 'G', 'GHI_w/m2': 74}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 22, 0, 0), 'datetime': datetime.datetime(2025, 4, 22, 4, 48), 'surface_temperature_celsius': 60.0, 'confidence': 88.0, 'latitude': -37.335, 'longitude': 148.064}, {'type': 'other', 'date': datetime.datetime(2025, 4, 21, 0, 0), 'datetime': datetime.datetime(2025, 4, 21, 0, 0), 'surface_temperature_celsius': 50.0, 'confidence': 66.0, 'latitude': -37.6865, 'longitude': 148.5154}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 24, 0, 0), 'station': 3314, 'relative_humidity': 57.4, 'air_temperature_celsius': 20, 'windspeed_knots': 10.9, 'max_wind_speed': 22.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 161}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 25, 0, 0), 'station': 922, 'relative_humidity': 44.1, 'air_temperature_celsius': 10, 'windspeed_knots': 7.3, 'max_wind_speed': 12.0, 'measure': 0.39, 'flag': 'G', 'GHI_w/m2': 90}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 23, 0, 0), 'datetime': datetime.datetime(2025, 4, 23, 14, 24), 'surface_temperature_celsius': 80.0, 'confidence': 97.0, 'latitude': -37.0924, 'longitude': 141.897}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 26, 0, 0), 'station': 1381, 'relative_humidity': 43.3, 'air_temperature_celsius': 12, 'windspeed_knots': 7.0, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 109}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 24, 0, 0), 'datetime': datetime.datetime(2025, 4, 24, 9, 36), 'surface_temperature_celsius': 48.0, 'confidence': 75.0, 'latitude': -36.9193, 'longitude': 141.068}, {'type': 'other', 'date': datetime.datetime(2025, 4, 25, 0, 0), 'datetime': datetime.datetime(2025, 4, 25, 0, 0), 'surface_temperature_celsius': 53.0, 'confidence': 79.0, 'latitude': -36.932, 'longitude': 141.9456}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 27, 0, 0), 'station': 4704, 'relative_humidity': 58.3, 'air_temperature_celsius': 25, 'windspeed_knots': 12.2, 'max_wind_speed': 22.0, 'measure': 0.04, 'flag': 'G', 'GHI_w/m2': 199}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 28, 0, 0), 'station': 6025, 'relative_humidity': 42.8, 'air_temperature_celsius': 9, 'windspeed_knots': 9.3, 'max_wind_speed': 13.0, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 82}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 4, 29, 0, 0), 'station': 4467, 'relative_humidity': 47.9, 'air_temperature_celsius': 14, 'windspeed_knots': 5.3, 'max_wind_speed': 9.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 122}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 4, 27, 0, 0), 'datetime': datetime.datetime(2025, 4, 27, 19, 12), 'surface_temperature_celsius': 45.0, 'confidence': 70.0, 'latitude': -37.7943, 'longitude': 143.0545}, {'type': 'other', 'date': datetime.datetime(2025, 4, 28, 0, 0), 'datetime': datetime.datetime(2025, 4, 28, 0, 0), 'surface_temperature_celsius': 81.0, 'confidence': 97.0, 'latitude': -36.6527, 'longitude': 142.7392}, {'type': 'other', 'date': datetime.datetime(2025, 4, 27, 0, 0), 'datetime': datetime.datetime(2025, 4, 27, 4, 48), 'surface_temperature_celsius': 49.0, 'confidence': 75.0, 'latitude': -37.5422, 'longitude': 143.2276}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 4, 30, 0, 0), 'station': 7395, 'relative_humidity': 49.5, 'air_temperature_celsius': 14, 'windspeed_knots': 6.0, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 121}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 1, 0, 0), 'station': 7892, 'relative_humidity': 51.5, 'air_temperature_celsius': 19, 'windspeed_knots': 10.2, 'max_wind_speed': 20.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 161}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 2, 0, 0), 'station': 8536, 'relative_humidity': 48.9, 'air_temperature_celsius': 16, 'windspeed_knots': 5.4, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 138}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 3, 0, 0), 'station': 7964, 'relative_humidity': 53.3, 'air_temperature_celsius': 18, 'windspeed_knots': 7.9, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 150}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 4, 0, 0), 'station': 3444, 'relative_humidity': 53.5, 'air_temperature_celsius': 20, 'windspeed_knots': 7.2, 'max_wind_speed': 15.9, 'measure': 0.31, 'flag': 'G', 'GHI_w/m2': 166}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 2, 0, 0), 'datetime': datetime.datetime(2025, 5, 2, 4, 48), 'surface_temperature_celsius': 65.0, 'confidence': 89.0, 'latitude': -35.4255, 'longitude': 143.6306}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 5, 0, 0), 'station': 451, 'relative_humidity': 42.4, 'air_temperature_celsius': 9, 'windspeed_knots': 7.2, 'max_wind_speed': 9.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 82}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 3, 0, 0), 'datetime': datetime.datetime(2025, 5, 3, 0, 0), 'surface_temperature_celsius': 44.0, 'confidence': 93.0, 'latitude': -36.087, 'longitude': 141.7227}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 6, 0, 0), 'station': 5239, 'relative_humidity': 45.7, 'air_temperature_celsius': 10, 'windspeed_knots': 3.6, 'max_wind_speed': 7.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 89}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 7, 0, 0), 'station': 1405, 'relative_humidity': 47.9, 'air_temperature_celsius': 12, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 105}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 5, 0, 0), 'datetime': datetime.datetime(2025, 5, 5, 14, 24), 'surface_temperature_celsius': 57.0, 'confidence': 84.0, 'latitude': -35.4993, 'longitude': 143.3105}, {'type': 'other', 'date': datetime.datetime(2025, 5, 5, 0, 0), 'datetime': datetime.datetime(2025, 5, 5, 4, 48), 'surface_temperature_celsius': 59.0, 'confidence': 80.0, 'latitude': -35.2397, 'longitude': 142.98}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 8, 0, 0), 'station': 647, 'relative_humidity': 40.7, 'air_temperature_celsius': 8, 'windspeed_knots': 5.3, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 74}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 9, 0, 0), 'station': 7846, 'relative_humidity': 48.7, 'air_temperature_celsius': 15, 'windspeed_knots': 8.5, 'max_wind_speed': 20.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 130}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 7, 0, 0), 'datetime': datetime.datetime(2025, 5, 7, 4, 48), 'surface_temperature_celsius': 68.0, 'confidence': 91.0, 'latitude': -36.3774, 'longitude': 143.7079}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 10, 0, 0), 'station': 1552, 'relative_humidity': 53.8, 'air_temperature_celsius': 18, 'windspeed_knots': 6.4, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 149}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 8, 0, 0), 'datetime': datetime.datetime(2025, 5, 8, 19, 12), 'surface_temperature_celsius': 58.0, 'confidence': 84.0, 'latitude': -35.9316, 'longitude': 143.9843}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 11, 0, 0), 'station': 3291, 'relative_humidity': 41.4, 'air_temperature_celsius': 10, 'windspeed_knots': 9.4, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 92}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 12, 0, 0), 'station': 538, 'relative_humidity': 47.3, 'air_temperature_celsius': 15, 'windspeed_knots': 8.6, 'max_wind_speed': 22.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 131}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 10, 0, 0), 'datetime': datetime.datetime(2025, 5, 10, 9, 36), 'surface_temperature_celsius': 45.0, 'confidence': 70.0, 'latitude': -37.2627, 'longitude': 141.8114}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 13, 0, 0), 'station': 3414, 'relative_humidity': 51.4, 'air_temperature_celsius': 13, 'windspeed_knots': 4.6, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 110}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 11, 0, 0), 'datetime': datetime.datetime(2025, 5, 11, 14, 24), 'surface_temperature_celsius': 92.0, 'confidence': 100.0, 'latitude': -35.8182, 'longitude': 143.8739}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 14, 0, 0), 'station': 6366, 'relative_humidity': 43.3, 'air_temperature_celsius': 8, 'windspeed_knots': 3.9, 'max_wind_speed': 8.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 72}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 15, 0, 0), 'station': 6818, 'relative_humidity': 50.7, 'air_temperature_celsius': 13, 'windspeed_knots': 6.1, 'max_wind_speed': 13.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 111}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 13, 0, 0), 'datetime': datetime.datetime(2025, 5, 13, 9, 36), 'surface_temperature_celsius': 46.0, 'confidence': 71.0, 'latitude': -36.686, 'longitude': 143.8575}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 16, 0, 0), 'station': 997, 'relative_humidity': 47.3, 'air_temperature_celsius': 12, 'windspeed_knots': 9.7, 'max_wind_speed': 14.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 105}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 14, 0, 0), 'datetime': datetime.datetime(2025, 5, 14, 19, 12), 'surface_temperature_celsius': 42.0, 'confidence': 65.0, 'latitude': -36.5664, 'longitude': 142.9892}, {'type': 'other', 'date': datetime.datetime(2025, 5, 15, 0, 0), 'datetime': datetime.datetime(2025, 5, 15, 0, 0), 'surface_temperature_celsius': 46.0, 'confidence': 72.0, 'latitude': -37.8328, 'longitude': 142.5142}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 17, 0, 0), 'station': 3317, 'relative_humidity': 60.8, 'air_temperature_celsius': 26, 'windspeed_knots': 6.9, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 203}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 18, 0, 0), 'station': 7376, 'relative_humidity': 43.4, 'air_temperature_celsius': 12, 'windspeed_knots': 9.3, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 109}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 19, 0, 0), 'station': 1950, 'relative_humidity': 45.6, 'air_temperature_celsius': 15, 'windspeed_knots': 10.2, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 133}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 16, 0, 0), 'datetime': datetime.datetime(2025, 5, 16, 19, 12), 'surface_temperature_celsius': 60.0, 'confidence': 85.0, 'latitude': -36.2805, 'longitude': 145.4377}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 20, 0, 0), 'station': 4644, 'relative_humidity': 61.9, 'air_temperature_celsius': 31, 'windspeed_knots': 14.1, 'max_wind_speed': 23.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 239}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 21, 0, 0), 'station': 376, 'relative_humidity': 48.5, 'air_temperature_celsius': 13, 'windspeed_knots': 7.1, 'max_wind_speed': 15.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 113}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 22, 0, 0), 'station': 5561, 'relative_humidity': 47.0, 'air_temperature_celsius': 12, 'windspeed_knots': 7.7, 'max_wind_speed': 15.0, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 105}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 23, 0, 0), 'station': 1388, 'relative_humidity': 52.6, 'air_temperature_celsius': 17, 'windspeed_knots': 10.3, 'max_wind_speed': 15.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 143}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 24, 0, 0), 'station': 4890, 'relative_humidity': 48.2, 'air_temperature_celsius': 11, 'windspeed_knots': 10.8, 'max_wind_speed': 22.9, 'measure': 0.59, 'flag': 'G', 'GHI_w/m2': 96}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 25, 0, 0), 'station': 4702, 'relative_humidity': 45.6, 'air_temperature_celsius': 10, 'windspeed_knots': 4.5, 'max_wind_speed': 7.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 89}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 26, 0, 0), 'station': 8734, 'relative_humidity': 50.4, 'air_temperature_celsius': 14, 'windspeed_knots': 12.8, 'max_wind_speed': 20.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 120}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 24, 0, 0), 'datetime': datetime.datetime(2025, 5, 24, 4, 48), 'surface_temperature_celsius': 50.0, 'confidence': 77.0, 'latitude': -37.956, 'longitude': 143.5461}, {'type': 'other', 'date': datetime.datetime(2025, 5, 24, 0, 0), 'datetime': datetime.datetime(2025, 5, 24, 0, 0), 'surface_temperature_celsius': 39.0, 'confidence': 81.0, 'latitude': -37.527, 'longitude': 143.4752}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 27, 0, 0), 'station': 5700, 'relative_humidity': 51.1, 'air_temperature_celsius': 18, 'windspeed_knots': 8.1, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 153}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 25, 0, 0), 'datetime': datetime.datetime(2025, 5, 25, 4, 48), 'surface_temperature_celsius': 71.0, 'confidence': 92.0, 'latitude': -36.663, 'longitude': 142.8567}, {'type': 'other', 'date': datetime.datetime(2025, 5, 25, 0, 0), 'datetime': datetime.datetime(2025, 5, 25, 19, 12), 'surface_temperature_celsius': 62.0, 'confidence': 87.0, 'latitude': -37.5991, 'longitude': 143.1517}, {'type': 'other', 'date': datetime.datetime(2025, 5, 25, 0, 0), 'datetime': datetime.datetime(2025, 5, 25, 0, 0), 'surface_temperature_celsius': 70.0, 'confidence': 92.0, 'latitude': -37.95, 'longitude': 142.366}, {'type': 'other', 'date': datetime.datetime(2025, 5, 25, 0, 0), 'datetime': datetime.datetime(2025, 5, 25, 14, 24), 'surface_temperature_celsius': 42.0, 'confidence': 65.0, 'latitude': -36.587, 'longitude': 142.87}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 28, 0, 0), 'station': 6737, 'relative_humidity': 55.4, 'air_temperature_celsius': 24, 'windspeed_knots': 5.9, 'max_wind_speed': 9.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 196}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 5, 29, 0, 0), 'station': 6801, 'relative_humidity': 55.8, 'air_temperature_celsius': 20, 'windspeed_knots': 10.5, 'max_wind_speed': 15.9, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 163}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 30, 0, 0), 'station': 4099, 'relative_humidity': 38.6, 'air_temperature_celsius': 8, 'windspeed_knots': 12.8, 'max_wind_speed': 18.1, 'measure': 0.31, 'flag': 'G', 'GHI_w/m2': 75}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 27, 0, 0), 'datetime': datetime.datetime(2025, 5, 27, 19, 12), 'surface_temperature_celsius': 43.0, 'confidence': 66.0, 'latitude': -36.0156, 'longitude': 143.2188}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 5, 31, 0, 0), 'station': 9746, 'relative_humidity': 47.0, 'air_temperature_celsius': 13, 'windspeed_knots': 7.9, 'max_wind_speed': 15.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 114}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 5, 29, 0, 0), 'datetime': datetime.datetime(2025, 5, 29, 14, 24), 'surface_temperature_celsius': 68.0, 'confidence': 91.0, 'latitude': -37.6171, 'longitude': 142.9426}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 1, 0, 0), 'station': 5622, 'relative_humidity': 49.4, 'air_temperature_celsius': 18, 'windspeed_knots': 9.3, 'max_wind_speed': 13.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 155}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 2, 0, 0), 'station': 5309, 'relative_humidity': 46.3, 'air_temperature_celsius': 17, 'windspeed_knots': 11.7, 'max_wind_speed': 20.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 150}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 3, 0, 0), 'station': 2583, 'relative_humidity': 43.5, 'air_temperature_celsius': 11, 'windspeed_knots': 13.1, 'max_wind_speed': 21.0, 'measure': 0.24, 'flag': 'G', 'GHI_w/m2': 99}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 1, 0, 0), 'datetime': datetime.datetime(2025, 6, 1, 9, 36), 'surface_temperature_celsius': 46.0, 'confidence': 78.0, 'latitude': -36.851, 'longitude': 148.117}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 4, 0, 0), 'station': 3381, 'relative_humidity': 43.6, 'air_temperature_celsius': 20, 'windspeed_knots': 10.3, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 181}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 3, 0, 0), 'datetime': datetime.datetime(2025, 6, 3, 0, 0), 'surface_temperature_celsius': 50.0, 'confidence': 77.0, 'latitude': -37.7376, 'longitude': 142.6328}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 5, 0, 0), 'station': 4351, 'relative_humidity': 53.8, 'air_temperature_celsius': 19, 'windspeed_knots': 9.2, 'max_wind_speed': 15.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 158}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 6, 0, 0), 'station': 8344, 'relative_humidity': 52.2, 'air_temperature_celsius': 26, 'windspeed_knots': 13.7, 'max_wind_speed': 16.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 219}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 6, 4, 0, 0), 'datetime': datetime.datetime(2025, 6, 4, 4, 48), 'surface_temperature_celsius': 56.0, 'confidence': 82.0, 'latitude': -36.7219, 'longitude': 141.0396}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 7, 0, 0), 'station': 1732, 'relative_humidity': 49.4, 'air_temperature_celsius': 12, 'windspeed_knots': 4.4, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 103}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 8, 0, 0), 'station': 2830, 'relative_humidity': 44.2, 'air_temperature_celsius': 19, 'windspeed_knots': 7.8, 'max_wind_speed': 15.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 171}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 6, 0, 0), 'datetime': datetime.datetime(2025, 6, 6, 9, 36), 'surface_temperature_celsius': 39.0, 'confidence': 57.0, 'latitude': -37.6345, 'longitude': 143.1335}, {'type': 'other', 'date': datetime.datetime(2025, 6, 6, 0, 0), 'datetime': datetime.datetime(2025, 6, 6, 0, 0), 'surface_temperature_celsius': 47.0, 'confidence': 62.0, 'latitude': -37.4784, 'longitude': 143.015}, {'type': 'other', 'date': datetime.datetime(2025, 6, 6, 0, 0), 'datetime': datetime.datetime(2025, 6, 6, 4, 48), 'surface_temperature_celsius': 62.0, 'confidence': 89.0, 'latitude': -37.329, 'longitude': 143.136}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 9, 0, 0), 'station': 7234, 'relative_humidity': 49.6, 'air_temperature_celsius': 23, 'windspeed_knots': 10.0, 'max_wind_speed': 19.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 198}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 10, 0, 0), 'station': 9148, 'relative_humidity': 40.7, 'air_temperature_celsius': 7, 'windspeed_knots': 3.7, 'max_wind_speed': 7.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 65}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 11, 0, 0), 'station': 284, 'relative_humidity': 52.8, 'air_temperature_celsius': 21, 'windspeed_knots': 4.1, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 176}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 12, 0, 0), 'station': 1547, 'relative_humidity': 36.0, 'air_temperature_celsius': 14, 'windspeed_knots': 15.9, 'max_wind_speed': 22.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 134}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 10, 0, 0), 'datetime': datetime.datetime(2025, 6, 10, 9, 36), 'surface_temperature_celsius': 44.0, 'confidence': 78.0, 'latitude': -37.235, 'longitude': 142.153}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 13, 0, 0), 'station': 2840, 'relative_humidity': 48.5, 'air_temperature_celsius': 13, 'windspeed_knots': 5.3, 'max_wind_speed': 11.1, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 113}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 14, 0, 0), 'station': 8058, 'relative_humidity': 58.3, 'air_temperature_celsius': 28, 'windspeed_knots': 9.3, 'max_wind_speed': 15.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 223}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 15, 0, 0), 'station': 135, 'relative_humidity': 44.9, 'air_temperature_celsius': 17, 'windspeed_knots': 16.1, 'max_wind_speed': 27.0, 'measure': 0.24, 'flag': 'G', 'GHI_w/m2': 152}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 16, 0, 0), 'station': 1481, 'relative_humidity': 44.5, 'air_temperature_celsius': 15, 'windspeed_knots': 10.2, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 134}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 14, 0, 0), 'datetime': datetime.datetime(2025, 6, 14, 9, 36), 'surface_temperature_celsius': 66.0, 'confidence': 89.0, 'latitude': -37.4843, 'longitude': 143.0592}, {'type': 'other', 'date': datetime.datetime(2025, 6, 14, 0, 0), 'datetime': datetime.datetime(2025, 6, 14, 14, 24), 'surface_temperature_celsius': 52.0, 'confidence': 79.0, 'latitude': -36.9514, 'longitude': 142.1899}, {'type': 'other', 'date': datetime.datetime(2025, 6, 14, 0, 0), 'datetime': datetime.datetime(2025, 6, 14, 9, 36), 'surface_temperature_celsius': 44.0, 'confidence': 68.0, 'latitude': -37.9309, 'longitude': 143.381}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 17, 0, 0), 'station': 4174, 'relative_humidity': 57.3, 'air_temperature_celsius': 21, 'windspeed_knots': 5.4, 'max_wind_speed': 9.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 169}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 18, 0, 0), 'station': 5928, 'relative_humidity': 41.8, 'air_temperature_celsius': 12, 'windspeed_knots': 14.7, 'max_wind_speed': 21.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 110}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 19, 0, 0), 'station': 3081, 'relative_humidity': 53.6, 'air_temperature_celsius': 17, 'windspeed_knots': 7.6, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 141}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 16, 0, 0), 'datetime': datetime.datetime(2025, 6, 16, 19, 12), 'surface_temperature_celsius': 54.0, 'confidence': 69.0, 'latitude': -36.4918, 'longitude': 142.2465}, {'type': 'other', 'date': datetime.datetime(2025, 6, 17, 0, 0), 'datetime': datetime.datetime(2025, 6, 17, 0, 0), 'surface_temperature_celsius': 57.0, 'confidence': 83.0, 'latitude': -35.4128, 'longitude': 143.2693}, {'type': 'other', 'date': datetime.datetime(2025, 6, 17, 0, 0), 'datetime': datetime.datetime(2025, 6, 17, 9, 36), 'surface_temperature_celsius': 45.0, 'confidence': 70.0, 'latitude': -36.0005, 'longitude': 143.1847}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 20, 0, 0), 'station': 9540, 'relative_humidity': 52.0, 'air_temperature_celsius': 18, 'windspeed_knots': 7.1, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 152}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 18, 0, 0), 'datetime': datetime.datetime(2025, 6, 18, 0, 0), 'surface_temperature_celsius': 46.0, 'confidence': 71.0, 'latitude': -35.9701, 'longitude': 145.7061}, {'type': 'other', 'date': datetime.datetime(2025, 6, 18, 0, 0), 'datetime': datetime.datetime(2025, 6, 18, 0, 0), 'surface_temperature_celsius': 71.0, 'confidence': 92.0, 'latitude': -36.1367, 'longitude': 145.2071}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 21, 0, 0), 'station': 4228, 'relative_humidity': 59.7, 'air_temperature_celsius': 19, 'windspeed_knots': 7.4, 'max_wind_speed': 14.0, 'measure': 0.63, 'flag': 'G', 'GHI_w/m2': 150}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 18, 0, 0), 'datetime': datetime.datetime(2025, 6, 18, 19, 12), 'surface_temperature_celsius': 41.0, 'confidence': 57.0, 'latitude': -36.925, 'longitude': 143.9798}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 22, 0, 0), 'station': 179, 'relative_humidity': 39.3, 'air_temperature_celsius': 14, 'windspeed_knots': 17.7, 'max_wind_speed': 30.9, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 131}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 20, 0, 0), 'datetime': datetime.datetime(2025, 6, 20, 4, 48), 'surface_temperature_celsius': 52.0, 'confidence': 66.0, 'latitude': -36.8004, 'longitude': 142.4415}, {'type': 'other', 'date': datetime.datetime(2025, 6, 20, 0, 0), 'datetime': datetime.datetime(2025, 6, 20, 14, 24), 'surface_temperature_celsius': 49.0, 'confidence': 75.0, 'latitude': -37.4716, 'longitude': 143.2027}, {'type': 'other', 'date': datetime.datetime(2025, 6, 19, 0, 0), 'datetime': datetime.datetime(2025, 6, 19, 14, 24), 'surface_temperature_celsius': 46.0, 'confidence': 72.0, 'latitude': -37.8328, 'longitude': 142.5142}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 23, 0, 0), 'station': 8168, 'relative_humidity': 58.3, 'air_temperature_celsius': 25, 'windspeed_knots': 7.1, 'max_wind_speed': 13.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 199}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 6, 21, 0, 0), 'datetime': datetime.datetime(2025, 6, 21, 14, 24), 'surface_temperature_celsius': 46.0, 'confidence': 72.0, 'latitude': -37.9171, 'longitude': 143.2873}, {'type': 'natural', 'date': datetime.datetime(2025, 6, 21, 0, 0), 'datetime': datetime.datetime(2025, 6, 21, 19, 12), 'surface_temperature_celsius': 51.0, 'confidence': 78.0, 'latitude': -36.9294, 'longitude': 142.7087}, {'type': 'natural', 'date': datetime.datetime(2025, 6, 20, 0, 0), 'datetime': datetime.datetime(2025, 6, 20, 14, 24), 'surface_temperature_celsius': 49.0, 'confidence': 75.0, 'latitude': -37.8717, 'longitude': 143.3652}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 24, 0, 0), 'station': 1813, 'relative_humidity': 43.8, 'air_temperature_celsius': 11, 'windspeed_knots': 6.5, 'max_wind_speed': 12.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 99}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 22, 0, 0), 'datetime': datetime.datetime(2025, 6, 22, 0, 0), 'surface_temperature_celsius': 55.0, 'confidence': 71.0, 'latitude': -37.367, 'longitude': 148.04}, {'type': 'other', 'date': datetime.datetime(2025, 6, 22, 0, 0), 'datetime': datetime.datetime(2025, 6, 22, 14, 24), 'surface_temperature_celsius': 46.0, 'confidence': 64.0, 'latitude': -37.7496, 'longitude': 148.3898}, {'type': 'other', 'date': datetime.datetime(2025, 6, 22, 0, 0), 'datetime': datetime.datetime(2025, 6, 22, 4, 48), 'surface_temperature_celsius': 56.0, 'confidence': 77.0, 'latitude': -37.7105, 'longitude': 148.6047}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 25, 0, 0), 'station': 7516, 'relative_humidity': 39.9, 'air_temperature_celsius': 10, 'windspeed_knots': 12.6, 'max_wind_speed': 16.9, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 93}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 23, 0, 0), 'datetime': datetime.datetime(2025, 6, 23, 19, 12), 'surface_temperature_celsius': 71.0, 'confidence': 84.0, 'latitude': -37.0193, 'longitude': 148.1459}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 6, 26, 0, 0), 'station': 2552, 'relative_humidity': 52.5, 'air_temperature_celsius': 14, 'windspeed_knots': 7.0, 'max_wind_speed': 13.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 118}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 6, 24, 0, 0), 'datetime': datetime.datetime(2025, 6, 24, 19, 12), 'surface_temperature_celsius': 90.0, 'confidence': 100.0, 'latitude': -36.6615, 'longitude': 144.6014}, {'type': 'other', 'date': datetime.datetime(2025, 6, 23, 0, 0), 'datetime': datetime.datetime(2025, 6, 23, 14, 24), 'surface_temperature_celsius': 42.0, 'confidence': 64.0, 'latitude': -37.954, 'longitude': 143.918}, {'type': 'other', 'date': datetime.datetime(2025, 6, 23, 0, 0), 'datetime': datetime.datetime(2025, 6, 23, 19, 12), 'surface_temperature_celsius': 70.0, 'confidence': 92.0, 'latitude': -37.6625, 'longitude': 144.287}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 6, 27, 0, 0), 'station': 8628, 'relative_humidity': 43.2, 'air_temperature_celsius': 11, 'windspeed_knots': 5.5, 'max_wind_speed': 8.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 100}
# ---------------NO FIRES NEARBY------------
# ...
# {'date': datetime.datetime(2025, 8, 11, 0, 0), 'station': 6949, 'relative_humidity': 45.3, 'air_temperature_celsius': 11, 'windspeed_knots': 10.6, 'max_wind_speed': 16.9, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 98}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 12, 0, 0), 'station': 7330, 'relative_humidity': 41.0, 'air_temperature_celsius': 9, 'windspeed_knots': 8.2, 'max_wind_speed': 9.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 83}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 11, 0, 0), 'datetime': datetime.datetime(2025, 8, 11, 14, 24), 'surface_temperature_celsius': 72.0, 'confidence': 61.0, 'latitude': -37.562, 'longitude': 148.05}, {'type': 'other', 'date': datetime.datetime(2025, 8, 11, 0, 0), 'datetime': datetime.datetime(2025, 8, 11, 4, 48), 'surface_temperature_celsius': 59.0, 'confidence': 87.0, 'latitude': -37.469, 'longitude': 148.103}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 13, 0, 0), 'station': 2965, 'relative_humidity': 45.0, 'air_temperature_celsius': 12, 'windspeed_knots': 10.5, 'max_wind_speed': 16.9, 'measure': 0.16, 'flag': 'G', 'GHI_w/m2': 107}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 12, 0, 0), 'datetime': datetime.datetime(2025, 8, 12, 4, 48), 'surface_temperature_celsius': 45.0, 'confidence': 71.0, 'latitude': -36.6667, 'longitude': 143.7526}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 14, 0, 0), 'station': 7801, 'relative_humidity': 34.9, 'air_temperature_celsius': 5, 'windspeed_knots': 4.3, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'A', 'GHI_w/m2': 48}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 13, 0, 0), 'datetime': datetime.datetime(2025, 8, 13, 9, 36), 'surface_temperature_celsius': 50.0, 'confidence': 77.0, 'latitude': -36.2115, 'longitude': 141.6878}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 15, 0, 0), 'station': 7618, 'relative_humidity': 43.6, 'air_temperature_celsius': 13, 'windspeed_knots': 9.0, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 117}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 16, 0, 0), 'station': 8955, 'relative_humidity': 61.0, 'air_temperature_celsius': 26, 'windspeed_knots': 9.3, 'max_wind_speed': 15.0, 'measure': 0.2, 'flag': 'G', 'GHI_w/m2': 202}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 8, 14, 0, 0), 'datetime': datetime.datetime(2025, 8, 14, 14, 24), 'surface_temperature_celsius': 42.0, 'confidence': 57.0, 'latitude': -35.9326, 'longitude': 143.9772}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 17, 0, 0), 'station': 4561, 'relative_humidity': 59.5, 'air_temperature_celsius': 21, 'windspeed_knots': 12.4, 'max_wind_speed': 21.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 166}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 18, 0, 0), 'station': 9923, 'relative_humidity': 36.3, 'air_temperature_celsius': 8, 'windspeed_knots': 6.3, 'max_wind_speed': 13.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 76}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 19, 0, 0), 'station': 3729, 'relative_humidity': 61.1, 'air_temperature_celsius': 21, 'windspeed_knots': 6.6, 'max_wind_speed': 11.1, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 163}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 18, 0, 0), 'datetime': datetime.datetime(2025, 8, 18, 9, 36), 'surface_temperature_celsius': 39.0, 'confidence': 80.0, 'latitude': -36.7507, 'longitude': 147.1308}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 20, 0, 0), 'station': 8233, 'relative_humidity': 59.7, 'air_temperature_celsius': 20, 'windspeed_knots': 8.6, 'max_wind_speed': 15.9, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 158}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 18, 0, 0), 'datetime': datetime.datetime(2025, 8, 18, 14, 24), 'surface_temperature_celsius': 93.0, 'confidence': 100.0, 'latitude': -37.297, 'longitude': 143.5753}, {'type': 'other', 'date': datetime.datetime(2025, 8, 18, 0, 0), 'datetime': datetime.datetime(2025, 8, 18, 9, 36), 'surface_temperature_celsius': 47.0, 'confidence': 67.0, 'latitude': -36.8254, 'longitude': 143.5602}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 21, 0, 0), 'station': 6934, 'relative_humidity': 48.2, 'air_temperature_celsius': 16, 'windspeed_knots': 9.9, 'max_wind_speed': 18.1, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 139}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 19, 0, 0), 'datetime': datetime.datetime(2025, 8, 19, 9, 36), 'surface_temperature_celsius': 86.0, 'confidence': 99.0, 'latitude': -37.6, 'longitude': 149.325}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 22, 0, 0), 'station': 5274, 'relative_humidity': 45.4, 'air_temperature_celsius': 11, 'windspeed_knots': 5.2, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'A', 'GHI_w/m2': 98}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 23, 0, 0), 'station': 4505, 'relative_humidity': 54.3, 'air_temperature_celsius': 19, 'windspeed_knots': 5.9, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 157}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 21, 0, 0), 'datetime': datetime.datetime(2025, 8, 21, 14, 24), 'surface_temperature_celsius': 91.0, 'confidence': 100.0, 'latitude': -37.3949, 'longitude': 147.0175}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 24, 0, 0), 'station': 5634, 'relative_humidity': 39.3, 'air_temperature_celsius': 8, 'windspeed_knots': 4.7, 'max_wind_speed': 13.0, 'measure': 0.02, 'flag': 'G', 'GHI_w/m2': 75}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 23, 0, 0), 'datetime': datetime.datetime(2025, 8, 23, 0, 0), 'surface_temperature_celsius': 49.0, 'confidence': 75.0, 'latitude': -37.8717, 'longitude': 143.3652}, {'type': 'other', 'date': datetime.datetime(2025, 8, 23, 0, 0), 'datetime': datetime.datetime(2025, 8, 23, 4, 48), 'surface_temperature_celsius': 54.0, 'confidence': 81.0, 'latitude': -37.8076, 'longitude': 142.1698}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 25, 0, 0), 'station': 4579, 'relative_humidity': 47.1, 'air_temperature_celsius': 13, 'windspeed_knots': 8.1, 'max_wind_speed': 12.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 114}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 26, 0, 0), 'station': 2907, 'relative_humidity': 51.9, 'air_temperature_celsius': 24, 'windspeed_knots': 7.3, 'max_wind_speed': 13.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 202}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 8, 24, 0, 0), 'datetime': datetime.datetime(2025, 8, 24, 14, 24), 'surface_temperature_celsius': 84.0, 'confidence': 98.0, 'latitude': -36.8742, 'longitude': 142.7177}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 27, 0, 0), 'station': 8984, 'relative_humidity': 40.4, 'air_temperature_celsius': 12, 'windspeed_knots': 5.9, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 111}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 25, 0, 0), 'datetime': datetime.datetime(2025, 8, 25, 4, 48), 'surface_temperature_celsius': 50.0, 'confidence': 76.0, 'latitude': -37.0221, 'longitude': 141.5517}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 28, 0, 0), 'station': 9142, 'relative_humidity': 55.6, 'air_temperature_celsius': 18, 'windspeed_knots': 8.2, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 147}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 26, 0, 0), 'datetime': datetime.datetime(2025, 8, 26, 19, 12), 'surface_temperature_celsius': 38.0, 'confidence': 50.0, 'latitude': -35.708, 'longitude': 143.7987}, {'type': 'other', 'date': datetime.datetime(2025, 8, 27, 0, 0), 'datetime': datetime.datetime(2025, 8, 27, 4, 48), 'surface_temperature_celsius': 52.0, 'confidence': 79.0, 'latitude': -36.5328, 'longitude': 144.7883}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 29, 0, 0), 'station': 3164, 'relative_humidity': 38.7, 'air_temperature_celsius': 17, 'windspeed_knots': 16.8, 'max_wind_speed': 22.9, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 159}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 8, 30, 0, 0), 'station': 6072, 'relative_humidity': 43.8, 'air_temperature_celsius': 8, 'windspeed_knots': 7.3, 'max_wind_speed': 14.0, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 72}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 28, 0, 0), 'datetime': datetime.datetime(2025, 8, 28, 19, 12), 'surface_temperature_celsius': 62.0, 'confidence': 87.0, 'latitude': -37.732, 'longitude': 148.6059}, {'type': 'other', 'date': datetime.datetime(2025, 8, 29, 0, 0), 'datetime': datetime.datetime(2025, 8, 29, 0, 0), 'surface_temperature_celsius': 41.0, 'confidence': 56.0, 'latitude': -37.559, 'longitude': 148.037}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 8, 31, 0, 0), 'station': 3419, 'relative_humidity': 39.0, 'air_temperature_celsius': 9, 'windspeed_knots': 5.6, 'max_wind_speed': 8.9, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 84}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 1, 0, 0), 'station': 3845, 'relative_humidity': 61.5, 'air_temperature_celsius': 18, 'windspeed_knots': 5.5, 'max_wind_speed': 11.1, 'measure': 0.28, 'flag': 'G', 'GHI_w/m2': 140}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 8, 30, 0, 0), 'datetime': datetime.datetime(2025, 8, 30, 14, 24), 'surface_temperature_celsius': 48.0, 'confidence': 74.0, 'latitude': -37.8704, 'longitude': 142.5842}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 9, 2, 0, 0), 'station': 4143, 'relative_humidity': 55.5, 'air_temperature_celsius': 18, 'windspeed_knots': 8.9, 'max_wind_speed': 15.0, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 147}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 9, 3, 0, 0), 'station': 7057, 'relative_humidity': 46.2, 'air_temperature_celsius': 13, 'windspeed_knots': 5.6, 'max_wind_speed': 12.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 115}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 4, 0, 0), 'station': 3101, 'relative_humidity': 67.4, 'air_temperature_celsius': 20, 'windspeed_knots': 8.5, 'max_wind_speed': 14.0, 'measure': 0.63, 'flag': 'G', 'GHI_w/m2': 147}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 9, 3, 0, 0), 'datetime': datetime.datetime(2025, 9, 3, 0, 0), 'surface_temperature_celsius': 44.0, 'confidence': 78.0, 'latitude': -36.834, 'longitude': 142.524}, {'type': 'other', 'date': datetime.datetime(2025, 9, 3, 0, 0), 'datetime': datetime.datetime(2025, 9, 3, 9, 36), 'surface_temperature_celsius': 40.0, 'confidence': 59.0, 'latitude': -36.8679, 'longitude': 142.7328}, {'type': 'other', 'date': datetime.datetime(2025, 9, 2, 0, 0), 'datetime': datetime.datetime(2025, 9, 2, 19, 12), 'surface_temperature_celsius': 70.0, 'confidence': 92.0, 'latitude': -36.882, 'longitude': 142.7108}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 5, 0, 0), 'station': 3455, 'relative_humidity': 47.2, 'air_temperature_celsius': 12, 'windspeed_knots': 8.8, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'G', 'GHI_w/m2': 105}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 9, 3, 0, 0), 'datetime': datetime.datetime(2025, 9, 3, 14, 24), 'surface_temperature_celsius': 45.0, 'confidence': 70.0, 'latitude': -36.3012, 'longitude': 141.163}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 6, 0, 0), 'station': 8125, 'relative_humidity': 44.7, 'air_temperature_celsius': 10, 'windspeed_knots': 8.0, 'max_wind_speed': 15.9, 'measure': 0.08, 'flag': 'G', 'GHI_w/m2': 90}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 9, 5, 0, 0), 'datetime': datetime.datetime(2025, 9, 5, 0, 0), 'surface_temperature_celsius': 48.0, 'confidence': 81.0, 'latitude': -37.376, 'longitude': 148.042}]
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 9, 7, 0, 0), 'station': 4138, 'relative_humidity': 39.0, 'air_temperature_celsius': 6, 'windspeed_knots': 1.8, 'max_wind_speed': 5.1, 'measure': 0.01, 'flag': 'G', 'GHI_w/m2': 56}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 9, 8, 0, 0), 'station': 8775, 'relative_humidity': 53.0, 'air_temperature_celsius': 18, 'windspeed_knots': 6.6, 'max_wind_speed': 14.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 150}
# ---------------NO FIRES NEARBY------------
# {'date': datetime.datetime(2025, 9, 9, 0, 0), 'station': 9441, 'relative_humidity': 60.5, 'air_temperature_celsius': 19, 'windspeed_knots': 7.0, 'max_wind_speed': 11.1, 'measure': 0.83, 'flag': 'G', 'GHI_w/m2': 149}
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 10, 0, 0), 'station': 5001, 'relative_humidity': 46.2, 'air_temperature_celsius': 11, 'windspeed_knots': 10.5, 'max_wind_speed': 15.0, 'measure': 0.28, 'flag': 'G', 'GHI_w/m2': 97}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 9, 8, 0, 0), 'datetime': datetime.datetime(2025, 9, 8, 19, 12), 'surface_temperature_celsius': 45.0, 'confidence': 70.0, 'latitude': -36.9576, 'longitude': 141.5387}, {'type': 'other', 'date': datetime.datetime(2025, 9, 9, 0, 0), 'datetime': datetime.datetime(2025, 9, 9, 9, 36), 'surface_temperature_celsius': 43.0, 'confidence': 66.0, 'latitude': -36.7937, 'longitude': 141.3669}, {'type': 'other', 'date': datetime.datetime(2025, 9, 9, 0, 0), 'datetime': datetime.datetime(2025, 9, 9, 0, 0), 'surface_temperature_celsius': 59.0, 'confidence': 84.0, 'latitude': -37.903, 'longitude': 141.0975}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 11, 0, 0), 'station': 4615, 'relative_humidity': 52.8, 'air_temperature_celsius': 22, 'windspeed_knots': 9.1, 'max_wind_speed': 15.0, 'measure': 0.0, 'flag': 'I', 'GHI_w/m2': 184}
# --------------FIRES-------------
# [{'type': 'natural', 'date': datetime.datetime(2025, 9, 10, 0, 0), 'datetime': datetime.datetime(2025, 9, 10, 0, 0), 'surface_temperature_celsius': 61.0, 'confidence': 87.0, 'latitude': -36.9345, 'longitude': 143.7675}]
# --------------CLIMATE-------------
# {'date': datetime.datetime(2025, 9, 12, 0, 0), 'station': 895, 'relative_humidity': 47.5, 'air_temperature_celsius': 12, 'windspeed_knots': 15.0, 'max_wind_speed': 18.1, 'measure': 0.2, 'flag': 'G', 'GHI_w/m2': 105}
# --------------FIRES-------------
# [{'type': 'other', 'date': datetime.datetime(2025, 9, 10, 0, 0), 'datetime': datetime.datetime(2025, 9, 10, 14, 24), 'surface_temperature_celsius': 59.0, 'confidence': 85.0, 'latitude': -36.7448, 'longitude': 141.8369}, {'type': 'other', 'date': datetime.datetime(2025, 9, 10, 0, 0), 'datetime': datetime.datetime(2025, 9, 10, 19, 12), 'surface_temperature_celsius': 45.0, 'confidence': 70.0, 'latitude': -37.4786, 'longitude': 141.4578}, {'type': 'other', 'date': datetime.datetime(2025, 9, 10, 0, 0), 'datetime': datetime.datetime(2025, 9, 10, 9, 36), 'surface_temperature_celsius': 40.0, 'confidence': 50.0, 'latitude': -37.0643, 'longitude': 141.8567}, {'type': 'other', 'date': datetime.datetime(2025, 9, 10, 0, 0), 'datetime': datetime.datetime(2025, 9, 10, 14, 24), 'surface_temperature_celsius': 54.0, 'confidence': 80.0, 'latitude': -36.8202, 'longitude': 141.802}]
